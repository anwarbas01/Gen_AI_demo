# %% [markdown]
# # **python basic -- practice**

# %% [markdown]
# ***Question 1***
#
# *print sum of x and y*

# %%
x=10
y=20

print(x+y)
# Out:
# 30

# %% [markdown]
# ***Question 2***
#
# *To print name*

# %%
name="shakirsaju"

print("hello",name)
# Out:
# hello shakirsaju

# %% [markdown]
# ***Question 3***
#
# *swap two varibales without a third number*

# %%
a=10
b=20

a,b=b,a

print("a=",a)
print("b=",b)
# Out:
# a= 20
# b= 10

# %% [markdown]
# ***Question 4***
#
# *Take user input for age*

# %%
age=int(input("Enter your age : "))

print("you are",age,"years old")
# Out:
# you are 22 years old

# %% [markdown]
# ***Question 6***
#
# *Find sum,difference,product,division and modulus*

# %%
a=20
b=6

print("sum =",a+b)
print("difference =",a-b)
print("product =",a*b)
print("division =",a/b)
print("modulus =",a%b)
# Out:
# sum = 26
# difference = 14
# product = 120
# division = 3.3333333333333335
# modulus = 2

# %% [markdown]
# ***Question 5***
#
# *check whether even or odd*

# %%
num=int(input("Enter a number :"))
result=["even","odd"][num%2]

print(result)
# Out:
# odd

# %% [markdown]
# ***Question 7***
#
# *positive,negative or zero*

# %%
num=int(input("Enter a number:"))

if num>0:
    print("positive")
elif num<0:
    print("negative")
else:
    print("zero")
# Out:
# negative
